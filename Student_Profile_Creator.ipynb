# %% [markdown]
# <a href="https://colab.research.google.com/github/narmadhabalaji/python_challenges/blob/main/Student_Profile_Creator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s1 = 'Aarav'
s2 = 'Riya'
s3 = 'Rohit'
a1 =15
a2=17
a3=14
fav_sub1= ['Maths', 'Physics', 'English']
fav_sub2= ['Tamil', 'Maths', 'Chemistry']
fav_sub3= ['History', 'Geography', 'Economics']

# %% [markdown]
# **STUDENT INFROMATION**

# %%
print(f'Student 1 info: \n{s1}, {a1}, {fav_sub1}')
print(f'\nStudent 2 info: \n{s2}, {a2}, {fav_sub2}')
print(f'\nStudent 3 info: \n{s3}, {a3}, {fav_sub3}')
# Out:
# Student 1 info:
# Aarav, 15, ['Maths', 'Physics', 'English', 'Chemistry']
#
# Student 2 info:
# Riya, 17, ['Tamil', 'Maths', 'Chemistry', 'History']
#
# Student 3 info:
# Rohit, 14, ['History', 'Geography', 'Economics', 'Civics']

# %% [markdown]
# **UPDATED SUBJECT LIST**

# %%
fav_sub1.append('Chemistry')
fav_sub2.append('History')
fav_sub3.append('Civics')
print("**UPDATED SUBJECT LISTS**\n")
print(f"{s1}'s Updated Fav Subjects: {fav_sub1}")
print(f"\n{s2}'s Updated Fav Subjects: {fav_sub2}")
print(f"\n{s3}'s Updated Fav Subjects: {fav_sub3}")
# Out:
# **UPDATED SUBJECT LISTS**
#
# Aarav's Updated Fav Subjects: ['Maths', 'Physics', 'English', 'Chemistry', 'Chemistry']
#
# Riya's Updated Fav Subjects: ['Tamil', 'Maths', 'Chemistry', 'History', 'History']
#
# Rohit's Updated Fav Subjects: ['History', 'Geography', 'Economics', 'Civics', 'Civics']
